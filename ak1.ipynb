# %% [markdown]
# Importing Libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.utils import to_categorical,plot_model
from tensorflow.keras.datasets import cifar10
from matplotlib import pyplot as pl

# %% [markdown]
# Using unpickle function to make train and test data

# %%
import numpy as np
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
X = unpickle("data_batch_1") 
X_train = X[b'data']
X_test = np.array(X[b'labels']).reshape((-1,1))

X_train.shape,Y_train.shape
# Out:
# ((10000, 3072), (50000, 10))

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
Z = unpickle("test_batch") 
Y_train = Z[b'data']
Y_test = np.array(Z[b'labels']).reshape((-1,1))

Y_test.shape, Y_test.shape
# Out:
# ((10000, 1), (10000, 1))

# %%
input_size = 32*32

# %%
X_train = np.reshape(X_train,[-1,input_size])
X_train = X_train.astype('float32') 
X_test = X_test.astype('float32') 
X_train / 255 
X_test / 255 
Y_train = np_utils.to_categorical(y_train, 10) 
Y_test = np_utils.to_categorical(y_test, 10)

# %%
model = Sequential()
model.add(Dense(150,input_dim = 32*32))
model.add(Dropout(0.1))
model.add(Dense(150, activation='tanh'))
model.add(Dropout(0.1))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_46 (Dense)            (None, 150)               153750
#
#  dropout_30 (Dropout)        (None, 150)               0
#
#  dense_47 (Dense)            (None, 150)               22650
#
#  dropout_31 (Dropout)        (None, 150)               0
#
#  dense_48 (Dense)            (None, 10)                1510
#
# =================================================================
# Total params: 177,910
# Trainable params: 177,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train, batch_size=32, epochs=10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 2022-12-09 11:50:20.058787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 745/750 [============================>.] - ETA: 0s - loss: 2.4063 - accuracy: 0.0983
# 2022-12-09 11:50:24.675371: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 750/750 [==============================] - 6s 7ms/step - loss: 2.4058 - accuracy: 0.0984 - val_loss: 2.3465 - val_accuracy: 0.0933
# Epoch 2/10
# 750/750 [==============================] - 5s 7ms/step - loss: 2.3476 - accuracy: 0.0986 - val_loss: 2.3177 - val_accuracy: 0.1007
# Epoch 3/10
# 750/750 [==============================] - 5s 7ms/step - loss: 2.3416 - accuracy: 0.1010 - val_loss: 2.3227 - val_accuracy: 0.1007
# Epoch 4/10
# 750/750 [==============================] - 6s 7ms/step - loss: 2.3310 - accuracy: 0.1045 - val_loss: 2.3213 - val_accuracy: 0.1023
# Epoch 5/10
# 750/750 [==============================] - 5s 7ms/step - loss: 2.3246 - accuracy: 0.1014 - val_loss: 2.3305 - val_accuracy: 0.1075
# Epoch 6/10
# 750/750 [==============================] - 6s 8ms/step - loss: 2.3265 - accuracy: 0.0967 - val_loss: 2.3309 - val_accuracy: 0.0992
# Epoch 7/10
# 750/750 [==============================] - 6s 7ms/step - loss: 2.3493 - accuracy: 0.0981 - val_loss: 2.3121 - val_accuracy: 0.1030
# Epoch 8/10
# 750/750 [==============================] - 5s 7ms/step - loss: 2.3366 - accuracy: 0.0978 - val_loss: 2.3192 - val_accuracy: 0.1023
# Epoch 9/10
# 750/750 [==============================] - 5s 7ms/step - loss: 2.3273 - accuracy: 0.1029 - val_loss: 2.3168 - val_accuracy: 0.1075
# Epoch 10/10
# 750/750 [==============================] - 5s 7ms/step - loss: 2.3270 - accuracy: 0.0979 - val_loss: 2.3100 - val_accuracy: 0.1075

# %%
plt.plot(history.history['accuracy'])
plt.show()

# %%
# Out:
# 2022-12-09 11:55:01.379465: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [172], in <cell line: 1>()
# ----> 1 _,acc = model.evaluate(X_test,Y_test,batch_size=32,verbose = 1)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential_19/dense_46/MatMul' defined at (most recent call last):
#     File "/Users/student/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/student/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/student/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/Users/student/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/Users/student/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/j_/18y1_2ks4r5bw96hc9sdzp_r0000gn/T/ipykernel_805/4016901495.py", line 1, in <cell line: 1>
#       _,acc = model.evaluate(X_test,Y_test,batch_size=32,verbose = 1)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1947, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1727, in test_function
#       return step_function(self, iterator)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1713, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1701, in run_step
#       outputs = model.test_step(data)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1665, in test_step
#       y_pred = self(x, training=False)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/layers/core/dense.py", line 241, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'sequential_19/dense_46/MatMul'
# Detected at node 'sequential_19/dense_46/MatMul' defined at (most recent call last):
#     File "/Users/student/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/student/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/student/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/Users/student/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/Users/student/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/j_/18y1_2ks4r5bw96hc9sdzp_r0000gn/T/ipykernel_805/4016901495.py", line 1, in <cell line: 1>
#       _,acc = model.evaluate(X_test,Y_test,batch_size=32,verbose = 1)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1947, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1727, in test_function
#       return step_function(self, iterator)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1713, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1701, in run_step
#       outputs = model.test_step(data)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1665, in test_step
#       y_pred = self(x, training=False)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/engine/base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/student/anaconda3/lib/python3.9/site-packages/keras/layers/core/dense.py", line 241, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'sequential_19/dense_46/MatMul'
# 2 root error(s) found.
#   (0) INVALID_ARGUMENT:  In[0] mismatch In[1] shape: 1 vs. 1024: [32,1] [1024,150] 0 0
# 	 [[{{node sequential_19/dense_46/MatMul}}]]
# 	 [[sequential_19/dense_48/Softmax/_10]]
#   (1) INVALID_ARGUMENT:  In[0] mismatch In[1] shape: 1 vs. 1024: [32,1] [1024,150] 0 0
# 	 [[{{node sequential_19/dense_46/MatMul}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_test_function_118484]
